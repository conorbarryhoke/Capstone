# %%
{'kind': 'youtube#videoListResponse',
 'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/EAlxtySoC9DrNiB64Hx0kP1Qtb8"',
 'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
 'items': [
            {
            'kind': 'youtube#video',
            'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/2OkW6TTRydesmU1sfdjFfBZgfTQ"',
            'id': 'vv-r6Z6o1AQ',
            'snippet': {
                'publishedAt': '2017-06-26T15:00:08.000Z',
                'channelId': 'UCo6DJdltbIub80bLiyJRv3w',
                'title': 'EXPERIMENT Car VS Fidget Spinner',
                'description': 'DeletedForReadability’
                'thumbnails': {
                    'default': {
                        'url': 'https://i.ytimg.com/vi/vv-r6Z6o1AQ/default.jpg',
                            'width': 120,
                            'height': 90},
                    'medium': {
                    'url': 'https://i.ytimg.com/vi/vv-r6Z6o1AQ/mqdefault.jpg',
                        'width': 320,
                        'height': 180},
                    'high': {
                    'url': 'https://i.ytimg.com/vi/vv-r6Z6o1AQ/hqdefault.jpg',
                        'width': 480,
                        'height': 360},
                    'standard': {
                    'url': 'https://i.ytimg.com/vi/vv-r6Z6o1AQ/sddefault.jpg',
                        'width': 640,
                        'height': 480},
                    'maxres': {
                    'url': 'https://i.ytimg.com/vi/vv-r6Z6o1AQ/maxresdefault.jpg',
                        'width': 1280,
                        'height': 720}
                    }, #End of Thumbnails
                'channelTitle': 'MrGear',
                'tags': [
                        'Life Hacks',
                        'Tricks',
                        'Tests',
                        'Ways',
                        'Experiments',
                        'Life Hack',
                        'Trick',
                        'Test',
                        'Way',
                        'Experiment',
                        'Fidget Spinner',
                        'Spinner',
                        'Spinners',
                        'Car',
                        'mrgear',
                        'EXPERIMENT Car VS Fidget Spinnerz
                        ], #Close tags
                'categoryId': '28',
                'liveBroadcastContent': 'none',
                'defaultLanguage': 'en-US',
                'localized': {
                    'title': 'EXPERIMENT Car VS Fidget Spinner',
                    'description': 'DeletedForReadability'
                    }
            }, #closes items[0]['snippet']
    'statistics': {
        'viewCount': '30260850',
        'likeCount': '56852',
        'dislikeCount': '25253',
        'favoriteCount': '0',
        'commentCount': '2676'}
}#closes items[0]
] #closes items list
}
